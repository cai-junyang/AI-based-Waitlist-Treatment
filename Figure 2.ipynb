# %%
import matplotlib.pyplot as plt
plt.rc('font', size=8, weight='normal')
fig, axes = plt.subplots(1, 2, figsize=(8, 3.2), dpi=300)
fig.subplots_adjust(wspace=0.25)


ax1 = axes[0]
ax1.plot([5,10,15,20,25], [1.1045, 0.7240000000000001, 0.5269999999999999, 0.385, 0.2624999999999998], c='tab:orange', linestyle='--', marker='o',
         markerfacecolor='none', label='Class A - simulation (exp. dist.)')
ax1.plot([5,10,15,20,25], [0, 0, 0, 0, 0], c='tab:orange', marker='x',label='Class A - fluid solution')

ax1.plot([5,10,15,20,25], [1.1195, 0.6915, 0.504, 0.3075, 0.3085],
         c='tab:green', linestyle='dotted', label='Class A - simulation (LN. dist.)')

ax1.plot([5,10,15,20,25], [182.86249999999995, 365.463, 544.5355, 728.8715, 913.4715], c='tab:blue', linestyle='--', marker='o',
         markerfacecolor='none', label='Class B - simulation (exp. dist.)')
ax1.plot([5,10,15,20,25], [183.14876033057854,
  366.2975206611571,
  549.4462809917355,
  732.5950413223142,
  915.7438016528927], c='tab:blue',  marker='x',label='Class B - fluid solution')
ax1.plot([5,10,15,20,25], [189.31350000000003,
  380.9525,
  569.7665000000001,
  756.0485000000001,
  945.6985000000001],
         c='tab:red', linestyle='dotted', label='Class B - simulation (LN. dist.)')

ax1.grid()
ax1.set_xlim(5, 25)
ax1.set_xticks([5,10,15,20,25])
ax1.set_title('Queue length')
ax1.set_xlabel(r'$N$',
           fontsize=10)


ax2 = axes[1]
ax2.plot([5,10,15,20,25], [3.676, 7.435499999999999, 11.025, 14.8565, 18.5075], c='tab:orange', linestyle='--', marker='o',
         markerfacecolor='none')
ax2.plot([5,10,15,20,25], [3.6977690126956735,
  7.395538025391347,
  11.093307038087021,
  14.791076050782694,
  18.48884506347837], marker='x', c='tab:orange')
ax2.plot([5,10,15,20,25], [3.7365, 7.3185, 11.0295, 14.874, 18.3975], 
         c='tab:green', linestyle='dotted')

ax2.plot([5,10,15,20,25], [1.3239999999999998, 2.5645000000000007, 3.975, 5.1435, 6.4925], c='tab:blue', linestyle='--', marker='o',
         markerfacecolor='none')
ax2.plot([5,10,15,20,25], [1.3022309873043265,
  2.604461974608653,
  3.906692961912979,
  5.208923949217306,
  6.511154936521631], marker='x', c='tab:blue')
ax2.plot([5,10,15,20,25], [1.2635, 2.6814999999999998, 3.9705, 5.1259999999999994, 6.6025],
         c='tab:red', linestyle='dotted')

ax2.grid()
ax2.set_xlim(5, 25)
ax2.set_xticks([5,10,15,20,25])
ax2.set_title('Server allocation')
ax2.set_xlabel(r'$N$',
           fontsize=10)
ax2.set_yticks([5,10,15,20])

handles, labels = ax1.get_legend_handles_labels()
fig.legend(handles, labels,
           loc='lower center',
           ncol=2,framealpha=0,
           fontsize=10,
           bbox_to_anchor=(0.5, -0.275))

plt.savefig('NE-1-new.pdf', dpi=500, bbox_inches='tight')
plt.show()
